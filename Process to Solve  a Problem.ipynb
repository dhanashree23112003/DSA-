# %%
'''
1. Analyze the problem
See the input, output and handle the constraints

2. Breakdown our problem into smaller subparts

3. Think twice code ones.

4. Remember the concepts

5. Take 2-3 examples. Clear out confusion/gap

6. Ask for an example to the interviewwr of that problem

7. Write psuedocode on paper

8.Dry run the solultion

9.
'''
